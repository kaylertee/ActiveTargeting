# %% [markdown]
# # BindCraftRun: Local Binder Design Starter
# Use this notebook to configure and launch BindCraft locally. It assumes your input structures live in `../InputTargets/` and that results should be written under `../Results/`.

# %% [markdown]
# # Changelog
#
# 28 Dec 2025:
# * Changed colabdesign_utils.py so that min_trajectory_plddt can be set to specify threshold at which "Trajectory starting confidence low (pLDDT < {}), skipping analysis and MPNN optimisation" will execute
# * Changed bindcraft.py to improve AA rejection logic when banned AA is passed to MPNN

# %% [markdown]
# ## Prerequisites
# - BindCraft repository cloned and `install_bindcraft.sh` completed.
# - Notebook running inside the `BindCraft` conda environment created by the installer.
# - AlphaFold2 weights downloaded during installation (default under `params/`).
# - CUDA-compatible NVIDIA GPU with drivers matching the selected CUDA runtime.
# - Target PDB files available in `../InputTargets/` (adjust the variables below if you store them elsewhere).

# %%
from pathlib import Path
import json
import subprocess
import shlex
import os

BINDCRAFT_ROOT = Path(r'/mnt/e/Code/BindCraft').resolve()
BINDCRAFT_SCRIPT = BINDCRAFT_ROOT / 'bindcraft' / 'bindcraft.py'

# Configure JAX environment variables for GPU memory management (Try uncommenting to reduce OOM issues)
# Prevent JAX from preallocating all GPU memory at startup
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
# Limit JAX to use at most 50% of available GPU memory
# os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.50"
# Disable TensorFlow unified memory to reduce memory pressure
# os.environ["TF_FORCE_UNIFIED_MEMORY"] = "0"
# Use default memory allocator for XLA Python client
# os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "default"


print(f"BindCraft root: {BINDCRAFT_ROOT}")
if 'CONDA_DEFAULT_ENV' in os.environ:
    print(f"Active conda env: {os.environ['CONDA_DEFAULT_ENV']}")
else:
    print('CONDA_DEFAULT_ENV not set; confirm you activated the BindCraft environment.')
# Out:
# BindCraft root: /mnt/e/Code/BindCraft
# Active conda env: BindCraft

# %%
# Confirm the GPU that BindCraft will see
try:
    subprocess.run(['nvidia-smi'], check=True)
except FileNotFoundError:
    print('nvidia-smi not found. Ensure the NVIDIA drivers are installed and visible in this environment.')
except subprocess.CalledProcessError as exc:
    print('nvidia-smi failed with exit code', exc.returncode)
# Out:
# Mon Dec 29 18:12:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.07             Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 Ti     On  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8             19W /  285W |    1365MiB /  12282MiB |     20%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              27      G   /Xwayland                             N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Configure target and output paths
# Update the variables below to point at your desired settings file, target PDB, and output directory. The defaults use the example `8Z8L.pdb` located in `../InputTargets/`.

# %%
# Core project defaults for a quick CCR4 phage-display run
BINDCRAFT_ROOT = Path(r'/mnt/e/Code/BindCraft').resolve()
BINDCRAFT_SCRIPT = BINDCRAFT_ROOT / 'bindcraft' / 'bindcraft.py'
SETTINGS_DIR = BINDCRAFT_ROOT / 'bindcraft' / 'settings_target'
FILTERS_DIR = BINDCRAFT_ROOT / 'bindcraft' / 'settings_filters'
ADVANCED_DIR = BINDCRAFT_ROOT / 'bindcraft' / 'settings_advanced'

#P51679_ccr4_phage
DESIGN_NAME = 'test'
FILTERS_JSON = FILTERS_DIR / 'peptide_relaxed_filters_phage.json'
ADVANCED_JSON = ADVANCED_DIR / 'P51679_ccr4_phage.json'

TARGETS_DIR = (BINDCRAFT_ROOT / 'InputTargets').resolve()
TARGET_PDB_NAME = 'MIN_ANCHOR_AF-P51679-F1-model_v6_trimmed_bundle.pdb'
TARGET_CHAIN = 'A'
HOTSPOT_RESIDUES = None
BINDER_LENGTH_RANGE = [18, 20]
TARGET_PDB = (TARGETS_DIR / TARGET_PDB_NAME).resolve()
if not TARGET_PDB.exists():
    raise FileNotFoundError(f'Target PDB {TARGET_PDB} not found. Update TARGET_PDB_NAME or TARGETS_DIR.')

RESULTS_BASE = (BINDCRAFT_ROOT / 'Results').resolve()
RESULTS_BASE.mkdir(parents=True, exist_ok=True)
DESIGN_OUTPUT = RESULTS_BASE / DESIGN_NAME
DESIGN_OUTPUT.mkdir(parents=True, exist_ok=True)

print(f'Design name       : {DESIGN_NAME}')
print(f'Filters file      : {FILTERS_JSON}')
print(f'Advanced file     : {ADVANCED_JSON}')
print(f'Targets directory : {TARGETS_DIR}')
print(f'Target PDB        : {TARGET_PDB}')
print(f'Target chain      : {TARGET_CHAIN}')
print(f'Hotspot residues  : {HOTSPOT_RESIDUES}')
print(f'Design output dir : {DESIGN_OUTPUT}')
# Out:
# Design name       : test
# Filters file      : /mnt/e/Code/BindCraft/bindcraft/settings_filters/peptide_relaxed_filters_phage.json
# Advanced file     : /mnt/e/Code/BindCraft/bindcraft/settings_advanced/P51679_ccr4_phage.json
# Targets directory : /mnt/e/Code/BindCraft/InputTargets
# Target PDB        : /mnt/e/Code/BindCraft/InputTargets/AF-P51679-F1-model_v6_trimmed_bundle.pdb
# Target chain      : A
# Hotspot residues  : None
# Design output dir : /mnt/e/Code/BindCraft/Results/test

# %% [markdown]
# ### Create or reuse a dedicated settings file
# Set `CREATE_SETTINGS_COPY = True` the first time you run for a new project. The template (`settings.json`) will be copied to `settings_target/<design name>.json`, with `design_path`, `binder_name`, and `starting_pdb` updated to match your local folders. If the file already exists it will be reused unless you enable `OVERWRITE_SETTINGS`.

# %%
# Use existing settings file without template generation
RUN_SETTINGS = SETTINGS_DIR / 'P51679_ccr4_phage.json'
print(f'Using settings file: {RUN_SETTINGS}')
# Out:
# Using settings file: /mnt/e/Code/BindCraft/bindcraft/settings_target/P51679_ccr4_phage.json

# %%
# Print summary of advanced settings

print('Advanced settings file in use:', ADVANCED_JSON)
with ADVANCED_JSON.open() as fh:
    advanced_cfg = json.load(fh)

summary_keys = ['number_of_final_designs','max_trajectories','min_trajectory_plddt','enable_mpnn','use_multimer_design','enable_rejection_check','force_reject_AA','omit_AAs','design_models_override','sample_models','num_recycles_design','num_recycles_validation','soft_iterations','temporary_iterations','hard_iterations','greedy_iterations','inter_contact_distance','inter_contact_number','weights_helicity','sampling_temp','max_mpnn_sequences','num_seqs','start_monitoring','save_design_animations','save_design_trajectory_plots']
for key in summary_keys:
    value = advanced_cfg.get(key, '<not present>')
    print(f'{key:>28}: {value}')
# Out:
# Advanced settings file in use: /mnt/e/Code/BindCraft/bindcraft/settings_advanced/P51679_ccr4_phage.json
#      number_of_final_designs: 5
#             max_trajectories: False
#         min_trajectory_plddt: 0.2
#                  enable_mpnn: True
#          use_multimer_design: True
#       enable_rejection_check: False
#              force_reject_AA: False
#                     omit_AAs: C
#       design_models_override: <not present>
#                sample_models: False
#          num_recycles_design: 1
#      num_recycles_validation: 1
#              soft_iterations: 75
#         temporary_iterations: 45
#              hard_iterations: 5
#            greedy_iterations: 15
#       inter_contact_distance: 14.0
#         inter_contact_number: 8
#             weights_helicity: 0.3
#                sampling_temp: 0.3
#           max_mpnn_sequences: 6
#                     num_seqs: 10
#             start_monitoring: 0
#       save_design_animations: False
# save_design_trajectory_plots: False

# %%
#Use a non-Qt backend. Switch matplotlib to Agg before importing anything that touches Qt:
#Solve dependency conflicts when running in Jupyter notebooks


import matplotlib
matplotlib.use("Agg")  # do this right after launching the kernel

# %% [markdown]
# ## Launch BindCraft
# Set `LAUNCH_RUN = True` when you are ready. The command runs in blocking mode; expect long runtimes for realistic designs. Interrupt the cell if you need to stop the run.

# %%
LAUNCH_RUN = True
additional_args = []

env = os.environ.copy()
conda_prefix = env.get('CONDA_PREFIX')
if not conda_prefix:
    raise RuntimeError('Activate the BindCraft environment before launching.')
existing_ld = env.get('LD_LIBRARY_PATH', '')
if existing_ld:
    env['LD_LIBRARY_PATH'] = '{}/lib:{}'.format(conda_prefix, existing_ld)
else:
    env['LD_LIBRARY_PATH'] = '{}/lib'.format(conda_prefix)

cmd = [
    'python', '-u', str(BINDCRAFT_SCRIPT),
    '--settings', str(RUN_SETTINGS),
    '--filters', str(FILTERS_JSON),
    '--advanced', str(ADVANCED_JSON),
] + additional_args

print('Command to run:')
print(' '.join(shlex.quote(part) for part in cmd))
print('LD_LIBRARY_PATH:', env['LD_LIBRARY_PATH'])

if LAUNCH_RUN:
    result = subprocess.run(cmd, cwd=BINDCRAFT_ROOT, env=env, check=False)
    print(f'BindCraft finished with exit code {result.returncode}')
else:
    print('Set LAUNCH_RUN = True to start the design run.')
# Out:
# Command to run:
# python -u /mnt/e/Code/BindCraft/bindcraft/bindcraft.py --settings /mnt/e/Code/BindCraft/bindcraft/settings_target/P51679_ccr4_phage.json --filters /mnt/e/Code/BindCraft/bindcraft/settings_filters/peptide_relaxed_filters_phage.json --advanced /mnt/e/Code/BindCraft/bindcraft/settings_advanced/P51679_ccr4_phage.json
# LD_LIBRARY_PATH: /root/miniconda3/envs/BindCraft/lib
# Available GPUs:
# NVIDIA GeForce RTX 4070 Ti1: gpu
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.conda.ubuntu.cxx11thread.serialization.Ubuntu.python310.Release 2025.41+release.de3cc17d509259e29147a2ed8f2a726d644e7e34 2025-10-06T16:25:46] retrieved from: http://www.pyrosetta.org
# Running binder design for target P51679_ccr4_phage
# Design settings used: P51679_ccr4_phage
# Filtering designs based on peptide_relaxed_filters_phage
# Starting trajectory: P51679_ccr4_phage_l18_s722445
# Stage 1: running (logits → soft)
# 1 models [0] recycles 0 hard 0 soft 0.01 temp 1 loss 5.75 helix 1.94 pae 0.75 i_pae 0.77 con 4.95 i_con 4.33 plddt 0.26 ptm 0.78 i_ptm 0.27
# 2 models [0] recycles 0 hard 0 soft 0.03 temp 1 loss 5.16 helix 1.51 pae 0.62 i_pae 0.64 con 4.73 i_con 3.82 plddt 0.30 ptm 0.79 i_ptm 0.44
# 3 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 5.31 helix 1.21 pae 0.69 i_pae 0.71 con 4.84 i_con 4.08 plddt 0.30 ptm 0.77 i_ptm 0.34
# 4 models [0] recycles 0 hard 0 soft 0.05 temp 1 loss 5.08 helix 1.34 pae 0.61 i_pae 0.62 con 4.74 i_con 3.77 plddt 0.36 ptm 0.79 i_ptm 0.47
# 5 models [0] recycles 0 hard 0 soft 0.07 temp 1 loss 4.95 helix 0.97 pae 0.62 i_pae 0.63 con 4.65 i_con 3.82 plddt 0.36 ptm 0.79 i_ptm 0.44
# 6 models [0] recycles 0 hard 0 soft 0.08 temp 1 loss 5.09 helix 1.04 pae 0.66 i_pae 0.67 con 4.66 i_con 3.97 plddt 0.30 ptm 0.78 i_ptm 0.37
# 7 models [0] recycles 0 hard 0 soft 0.09 temp 1 loss 4.99 helix 1.43 pae 0.58 i_pae 0.59 con 4.72 i_con 3.62 plddt 0.37 ptm 0.79 i_ptm 0.54
# 8 models [0] recycles 0 hard 0 soft 0.11 temp 1 loss 4.96 helix 1.23 pae 0.66 i_pae 0.67 con 4.32 i_con 3.94 plddt 0.29 ptm 0.78 i_ptm 0.38
# 9 models [0] recycles 0 hard 0 soft 0.12 temp 1 loss 4.81 helix 1.21 pae 0.62 i_pae 0.64 con 4.23 i_con 3.80 plddt 0.32 ptm 0.78 i_ptm 0.45
# 10 models [0] recycles 0 hard 0 soft 0.13 temp 1 loss 4.80 helix 1.11 pae 0.59 i_pae 0.60 con 4.42 i_con 3.70 plddt 0.35 ptm 0.79 i_ptm 0.50
# 11 models [0] recycles 0 hard 0 soft 0.15 temp 1 loss 4.85 helix 0.82 pae 0.58 i_pae 0.59 con 4.68 i_con 3.73 plddt 0.35 ptm 0.79 i_ptm 0.48
# 12 models [0] recycles 0 hard 0 soft 0.16 temp 1 loss 4.85 helix 1.31 pae 0.59 i_pae 0.60 con 4.40 i_con 3.70 plddt 0.34 ptm 0.79 i_ptm 0.50
# 13 models [0] recycles 0 hard 0 soft 0.17 temp 1 loss 4.82 helix 1.22 pae 0.61 i_pae 0.62 con 4.31 i_con 3.75 plddt 0.32 ptm 0.79 i_ptm 0.47
# 14 models [0] recycles 0 hard 0 soft 0.19 temp 1 loss 5.14 helix 0.90 pae 0.70 i_pae 0.72 con 4.62 i_con 4.14 plddt 0.28 ptm 0.77 i_ptm 0.32
models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.82 helix 1.14 pae 0.67 i_pae 0.68 con 3.98 i_con 4.03 plddt 0.29 ptm 0.79 i_ptm 0.37
# 122 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.80 helix 1.41 pae 0.60 i_pae 0.61 con 4.17 i_con 3.74 plddt 0.30 ptm 0.80 i_ptm 0.49
# 123 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.63 helix 1.16 pae 0.59 i_pae 0.61 con 3.99 i_con 3.75 plddt 0.30 ptm 0.79 i_ptm 0.48
# 124 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.77 helix 1.26 pae 0.63 i_pae 0.64 con 4.04 i_con 3.87 plddt 0.30 ptm 0.79 i_ptm 0.42
# 125 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.01 helix 1.68 pae 0.63 i_pae 0.65 con 4.26 i_con 3.87 plddt 0.27 ptm 0.79 i_ptm 0.43
# Severe clashes detected, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 24 minutes, 54 seconds
#
# Starting trajectory: P51679_ccr4_phage_l20_s138545
# Stage 1: running (logits → soft)
# 1 models [0] recycles 0 hard 0 soft 0.01 temp 1 loss 5.50 helix 1.76 pae 0.68 i_pae 0.70 con 4.93 i_con 4.05 plddt 0.26 ptm 0.78 i_ptm 0.35
# 2 models [0] recycles 0 hard 0 soft 0.03 temp 1 loss 5.64 helix 0.98 pae 0.77 i_pae 0.80 con 5.14 i_con 4.47 plddt 0.28 ptm 0.77 i_ptm 0.22
# 3 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 5.27 helix 1.05 pae 0.64 i_pae 0.66 con 5.07 i_con 3.95 plddt 0.30 ptm 0.78 i_ptm 0.41
# 4 models [0] recycles 0 hard 0 soft 0.05 temp 1 loss 5.28 helix 1.08 pae 0.67 i_pae 0.69 con 4.99 i_con 3.98 plddt 0.33 ptm 0.78 i_ptm 0.38
# 5 models [0] recycles 0 hard 0 soft 0.07 temp 1 loss 5.20 helix 1.23 pae 0.66 i_pae 0.68 con 4.76 i_con 3.98 plddt 0.30 ptm 0.78 i_ptm 0.40
# 6 models [0] recycles 0 hard 0 soft 0.08 temp 1 loss 5.14 helix 1.20 pae 0.66 i_pae 0.68 con 4.68 i_con 3.96 plddt 0.30 ptm 0.78 i_ptm 0.38
# 7 models [0] recycles 0 hard 0 soft 0.09 temp 1 loss 5.16 helix 1.72 pae 0.65 i_pae 0.66 con 4.46 i_con 3.92 plddt 0.29 ptm 0.79 i_ptm 0.41
# 8 models [0] recycles 0 hard 0 soft 0.11 temp 1 loss 5.00 helix 1.20 pae 0.64 i_pae 0.65 con 4.51 i_con 3.89 plddt 0.32 ptm 0.78 i_ptm 0.43
# 9 models [0] recycles 0 hard 0 soft 0.12 temp 1 loss 5.00 helix 1.10 pae 0.65 i_pae 0.67 con 4.44 i_con 3.99 plddt 0.29 ptm 0.78 i_ptm 0.40
# 10 models [0] recycles 0 hard 0 soft 0.13 temp 1 loss 4.94 helix 1.15 pae 0.62 i_pae 0.64 con 4.48 i_con 3.85 plddt 0.30 ptm 0.78 i_ptm 0.46
# 26 models [0] recycles 0 hard 0 soft 0.35 temp 1 loss 4.61 helix 0.97 pae 0.60 i_pae 0.61 con 4.03 i_con 3.78 plddt 0.33 ptm 0.78 i_ptm 0.48
# 27 models [0] recycles 0 hard 0 soft 0.36 temp 1 loss 4.63 helix 0.84 pae 0.62 i_pae 0.64 con 4.02 i_con 3.87 plddt 0.34 ptm 0.78 i_ptm 0.44
# 28 models [0] recycles 0 hard 0 soft 0.37 temp 1 loss 4.73 helix 1.04 pae 0.62 i_pae 0.63 con 4.17 i_con 3.81 plddt 0.33 ptm 0.79 i_ptm 0.46
# 29 models [0] recycles 0 hard 0 soft 0.39 temp 1 loss 4.66 helix 0.85 pae 0.61 i_pae 0.63 con 4.10 i_con 3.86 plddt 0.33 ptm 0.78 i_ptm 0.44
# 30 models [0] recycles 0 hard 0 soft 0.40 temp 1 loss 4.70 helix 1.01 pae 0.61 i_pae 0.62 con 4.13 i_con 3.82 plddt 0.33 ptm 0.78 i_ptm 0.46
# 31 models [0] recycles 0 hard 0 soft 0.41 temp 1 loss 4.58 helix 0.87 pae 0.60 i_pae 0.61 con 4.03 i_con 3.79 plddt 0.35 ptm 0.79 i_ptm 0.47
# 32 models [0] recycles 0 hard 0 soft 0.43 temp 1 loss 4.63 helix 0.94 pae 0.61 i_pae 0.63 con 4.00 i_con 3.85 plddt 0.35 ptm 0.78 i_ptm 0.45
# 33 models [0] recycles 0 hard 0 soft 0.44 temp 1 loss 4.65 helix 0.97 pae 0.61 i_pae 0.62 con 4.06 i_con 3.81 plddt 0.35 ptm 0.78 i_ptm 0.46
# 34 models [0] recycles 0 hard 0 soft 0.45 temp 1 loss 4.63 helix 0.88 pae 0.64 i_pae 0.66 con 3.94 i_con 3.91 plddt 0.33 ptm 0.78 i_ptm 0.40
# 35 models [0] recycles 0 hard 0 soft 0.47 temp 1 loss 4.55 helix 0.95 pae 0.61 i_pae 0.62 con 3.87 i_con 3.81 plddt 0.35 ptm 0.78 i_ptm 0.44
# 36 models [0] recycles 0 hard 0 soft 0.48 temp 1 loss 4.77 helix 0.98 pae 0.63 i_pae 0.65 con 4.21 i_con 3.87 plddt 0.33 ptm 0.78 i_ptm 0.42
# 37 models [0] recycles 0 hard 0 soft 0.49 temp 1 loss 4.72 helix 1.08 pae 0.63 i_pae 0.65 con 4.06 i_con 3.86 plddt 0.33 ptm 0.78 i_ptm 0.42
# 38 models [0] recycles 1 hard 0 soft 0.51 temp 1 loss 4.78 helix 1.17 pae 0.64 i_pae 0.66 con 4.04 i_con 3.91 plddt 0.33 ptm 0.78 i_ptm 0.42
# 39 models [0] recycles 1 hard 0 soft 0.52 temp 1 loss 4.67 helix 1.07 pae 0.62 i_pae 0.64 con 4.00 i_con 3.83 plddt 0.34 ptm 0.78 i_ptm 0.44
# 40 models [0] recycles 1 hard 0 soft 0.53 temp 1 loss 4.72 helix 0.92 pae 0.64 i_pae 0.66 con 4.04 i_con 3.96 plddt 0.33 ptm 0.77 i_ptm 0.40
models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.86 helix 0.86 pae 0.68 i_pae 0.70 con 4.12 i_con 4.13 plddt 0.34 ptm 0.77 i_ptm 0.35
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 5.28 helix 0.70 pae 0.84 i_pae 0.87 con 3.98 i_con 4.97 plddt 0.30 ptm 0.76 i_ptm 0.15
# 119 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.80 helix 0.89 pae 0.65 i_pae 0.67 con 4.18 i_con 3.97 plddt 0.34 ptm 0.78 i_ptm 0.39
# 120 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.50 helix 0.70 pae 0.61 i_pae 0.63 con 3.89 i_con 3.83 plddt 0.37 ptm 0.78 i_ptm 0.45
# Stage 3: running (hard)
# 121 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.06 helix 0.72 pae 0.79 i_pae 0.82 con 3.88 i_con 4.68 plddt 0.29 ptm 0.78 i_ptm 0.21
# 122 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.91 helix 0.90 pae 0.68 i_pae 0.70 con 4.21 i_con 4.12 plddt 0.29 ptm 0.78 i_ptm 0.35
# 123 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.02 helix 0.71 pae 0.77 i_pae 0.80 con 3.91 i_con 4.60 plddt 0.29 ptm 0.78 i_ptm 0.23
# 124 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.91 helix 0.90 pae 0.68 i_pae 0.70 con 4.21 i_con 4.12 plddt 0.29 ptm 0.78 i_ptm 0.35
# 125 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.02 helix 0.71 pae 0.77 i_pae 0.80 con 3.91 i_con 4.60 plddt 0.29 ptm 0.78 i_ptm 0.23
# Trajectory successful, final pLDDT: 0.37
# Starting trajectory took: 0 hours, 23 minutes, 23 seconds
#
# Fixing interface residues: B2,B3,B4,B5,B6,B7,B8,B9,B10,B11,B12,B13,B14,B15,B16,B17,B18,B19,B20
# Rejected 6 duplicate MPNN sequences within this batch.
# Base AF2 filters not passed for P51679_ccr4_phage_l20_s138545_mpnn1, skipping interface scoring
# Base AF2 filters not passed for P51679_ccr4_phage_l20_s138545_mpnn2, skipping interface scoring
# Base AF2 filters not passed for P51679_ccr4_phage_l20_s138545_mpnn3, skipping interface scoring
# Base AF2 filters not passed for P51679_ccr4_phage_l20_s138545_mpnn4, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
#
# Design and validation of trajectory P51679_ccr4_phage_l20_s138545 took: 0 hours, 1 minutes, 3 seconds
# Starting trajectory: P51679_ccr4_phage_l13_s499725
# Stage 1: running (logits → soft)
# 1 models [0] recycles 0 hard 0 soft 0.01 temp 1 loss 4.53 helix 1.97 pae 0.67 i_pae 0.69 con 2.96 i_con 3.98 plddt 0.27 ptm 0.79 i_ptm 0.37
# 2 models [0] recycles 0 hard 0 soft 0.03 temp 1 loss 4.56 helix 1.64 pae 0.75 i_pae 0.77 con 2.88 i_con 4.20 plddt 0.24 ptm 0.78 i_ptm 0.27
# 3 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 4.20 helix 1.32 pae 0.62 i_pae 0.63 con 2.97 i_con 3.77 plddt 0.30 ptm 0.79 i_ptm 0.47
# 115 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 4.08 helix 1.12 pae 0.57 i_pae 0.58 con 3.03 i_con 3.68 plddt 0.40 ptm 0.79 i_ptm 0.52
# 116 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 4.34 helix 1.28 pae 0.62 i_pae 0.63 con 3.26 i_con 3.81 plddt 0.34 ptm 0.79 i_ptm 0.47
# 117 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.36 helix 1.19 pae 0.64 i_pae 0.65 con 3.23 i_con 3.90 plddt 0.30 ptm 0.78 i_ptm 0.42
# 118 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.34 helix 1.09 pae 0.65 i_pae 0.66 con 3.19 i_con 3.93 plddt 0.32 ptm 0.78 i_ptm 0.40
# 119 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.18 helix 1.24 pae 0.58 i_pae 0.59 con 3.15 i_con 3.67 plddt 0.37 ptm 0.79 i_ptm 0.54
# 120 models [0] recycles 1 hard 0 soft 1 temp 0.01 loss 4.37 helix 1.36 pae 0.60 i_pae 0.62 con 3.33 i_con 3.77 plddt 0.34 ptm 0.79 i_ptm 0.49
# Stage 3: running (hard)
# 121 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.41 helix 1.16 pae 0.64 i_pae 0.65 con 3.29 i_con 3.94 plddt 0.27 ptm 0.80 i_ptm 0.42
# 122 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.44 helix 1.39 pae 0.64 i_pae 0.65 con 3.23 i_con 3.94 plddt 0.31 ptm 0.80 i_ptm 0.44
# 123 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.44 helix 1.39 pae 0.64 i_pae 0.65 con 3.23 i_con 3.94 plddt 0.31 ptm 0.80 i_ptm 0.44
# 124 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.44 helix 1.39 pae 0.64 i_pae 0.65 con 3.23 i_con 3.94 plddt 0.31 ptm 0.80 i_ptm 0.44
# 125 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.44 helix 1.39 pae 0.64 i_pae 0.65 con 3.23 i_con 3.94 plddt 0.31 ptm 0.80 i_ptm 0.44
# Trajectory successful, final pLDDT: 0.45
# Starting trajectory took: 0 hours, 59 minutes, 3 seconds
#
# Fixing interface residues: B1,B2,B3,B4,B5,B6,B7,B8,B9,B10,B11,B12,B13,B14,B15
# Rejected 9 duplicate MPNN sequences within this batch.
# Base AF2 filters not passed for P51679_ccr4_phage_l15_s18761_mpnn1, skipping interface scoring
# No accepted MPNN designs found for this trajectory.
#
# Design and validation of trajectory P51679_ccr4_phage_l15_s18761 took: 0 hours, 0 minutes, 49 seconds
# Starting trajectory: P51679_ccr4_phage_l17_s129036
# Stage 1: running (logits → soft)
# 1 models [0] recycles 0 hard 0 soft 0.01 temp 1 loss 5.56 helix 1.67 pae 0.77 i_pae 0.78 con 4.64 i_con 4.40 plddt 0.23 ptm 0.78 i_ptm 0.24
# 2 models [0] recycles 0 hard 0 soft 0.03 temp 1 loss 5.10 helix 1.63 pae 0.63 i_pae 0.65 con 4.48 i_con 3.85 plddt 0.30 ptm 0.79 i_ptm 0.41
# 3 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 5.03 helix 1.72 pae 0.60 i_pae 0.62 con 4.41 i_con 3.77 plddt 0.29 ptm 0.79 i_ptm 0.47
# 49 models [0] recycles 1 hard 0 soft 0.65 temp 1 loss 4.61 helix 1.20 pae 0.63 i_pae 0.64 con 3.79 i_con 3.84 plddt 0.31 ptm 0.79 i_ptm 0.44
# 50 models [0] recycles 1 hard 0 soft 0.67 temp 1 loss 4.75 helix 1.13 pae 0.68 i_pae 0.69 con 3.86 i_con 4.02 plddt 0.29 ptm 0.78 i_ptm 0.37
# 51 models [0] recycles 1 hard 0 soft 0.68 temp 1 loss 4.56 helix 1.08 pae 0.62 i_pae 0.63 con 3.78 i_con 3.84 plddt 0.34 ptm 0.78 i_ptm 0.46
# 52 models [0] recycles 1 hard 0 soft 0.69 temp 1 loss 4.71 helix 1.23 pae 0.65 i_pae 0.66 con 3.88 i_con 3.90 plddt 0.29 ptm 0.78 i_ptm 0.40
# 53 models [0] recycles 1 hard 0 soft 0.71 temp 1 loss 4.56 helix 1.15 pae 0.62 i_pae 0.63 con 3.77 i_con 3.80 plddt 0.32 ptm 0.79 i_ptm 0.45
# 54 models [0] recycles 1 hard 0 soft 0.72 temp 1 loss 4.60 helix 1.10 pae 0.64 i_pae 0.65 con 3.78 i_con 3.87 plddt 0.31 ptm 0.78 i_ptm 0.42
# 55 models [0] recycles 1 hard 0 soft 0.73 temp 1 loss 4.60 helix 1.19 pae 0.62 i_pae 0.64 con 3.82 i_con 3.80 plddt 0.33 ptm 0.78 i_ptm 0.45
# 56 models [0] recycles 1 hard 0 soft 0.75 temp 1 loss 4.62 helix 1.13 pae 0.64 i_pae 0.66 con 3.81 i_con 3.87 plddt 0.31 ptm 0.79 i_ptm 0.43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 26
#      23 print('LD_LIBRARY_PATH:', env['LD_LIBRARY_PATH'])
#      25 if LAUNCH_RUN:
# ---> 26     result = subprocess.run(cmd, cwd=BINDCRAFT_ROOT, env=env, check=False)
#      27     print(f'BindCraft finished with exit code {result.returncode}')
#      28 else:
#
# File ~/miniconda3/envs/BindCraft/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniconda3/envs/BindCraft/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/miniconda3/envs/BindCraft/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/miniconda3/envs/BindCraft/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/miniconda3/envs/BindCraft/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# ## Inspect recent outputs
# Use the helper below to list the most recently modified files under your design directory once a run has started producing results.

# %%
from datetime import datetime

if DESIGN_OUTPUT.exists():
    tracked_files = sorted(
        (path for path in DESIGN_OUTPUT.glob('**/*') if path.is_file()),
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )[:10]
    if tracked_files:
        print('Latest files:')
        for path in tracked_files:
            timestamp = datetime.fromtimestamp(path.stat().st_mtime).isoformat(sep=' ', timespec='seconds')
            print(f'{timestamp} :: {path.relative_to(DESIGN_OUTPUT)}')
    else:
        print('No files in the design output directory yet.')
else:
    print('Design output directory does not exist. Run the configuration cells first.')
# Out:
# Latest files:
# 2025-12-27 22:02:23 :: failure_csv.csv
# 2025-12-27 22:02:23 :: final_design_stats.csv
# 2025-12-27 22:02:23 :: mpnn_design_stats.csv
# 2025-12-27 22:02:23 :: trajectory_stats.csv
